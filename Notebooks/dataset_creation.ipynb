# %%
# Для обработки данных
import pandas as pd
import numpy as np

# Для обработки аудио
import librosa
from pydub import AudioSegment

# Для скачивания аудио с ютуба и сохранения локально
import os
from pytube import Playlist

# Для разбиения на train/test
from sklearn.model_selection import train_test_split

# %% [markdown]
# ## Extracting main audio features

# %%
def extract_audio_features(file_path):
    
    y, sr = librosa.load(file_path)

    rmse = librosa.feature.rms(y=y)
    spectral_centroid = librosa.feature.spectral_centroid(y=y, sr=sr)
    spectral_bandwidth = librosa.feature.spectral_bandwidth(y=y, sr=sr)
    rolloff = librosa.feature.spectral_rolloff(y=y, sr=sr)
    zero_crossing_rate = librosa.feature.zero_crossing_rate(y=y)
    mfcc = librosa.feature.mfcc(y=y, sr=sr, n_mfcc=40)
    chroma = librosa.feature.chroma_stft(y=y, sr=sr)
    tonnetz = librosa.feature.tonnetz(y=y, sr=sr)
    chroma_cqt = librosa.feature.chroma_cqt(y=y, sr=sr)
    spectral_contrast = librosa.feature.spectral_contrast(y=y, sr=sr)

    features = {
        'rmse_mean': np.mean(rmse),
        'rmse_std': np.std(rmse),
        'spectral_centroid_mean': np.mean(spectral_centroid),
        'spectral_centroid_std': np.std(spectral_centroid),
        'spectral_bandwidth_mean': np.mean(spectral_bandwidth),
        'spectral_bandwidth_std': np.std(spectral_bandwidth),
        'rolloff_mean': np.mean(rolloff),
        'rolloff_std': np.std(rolloff),
        'zero_crossing_rate_mean': np.mean(zero_crossing_rate),
        'zero_crossing_rate_std': np.std(zero_crossing_rate),
    }

    for i in range(1, 41):
        features[f'mfcc{i}_mean'] = np.mean(mfcc[i-1])
        features[f'mfcc{i}_std'] = np.std(mfcc[i-1])

    for i in range(1, 13):
        features[f'chroma{i}_mean'] = np.mean(chroma[i-1])
        features[f'chroma{i}_std'] = np.std(chroma[i-1])

    for i in range(1, 7):
        features[f'tonnetz{i}_mean'] = np.mean(tonnetz[i-1])
        features[f'tonnetz{i}_std'] = np.std(tonnetz[i-1])

    features['chroma_cqt_mean'] = np.mean(chroma_cqt)
    features['chroma_cqt_std'] = np.std(chroma_cqt)

    features['spectral_contrast_mean'] = np.mean(spectral_contrast)
    features['spectral_contrast_std'] = np.std(spectral_contrast)

    return features

# %% [markdown]
# ## Downloading youtube playlists with music

# %%
def download_audio_from_playlist(playlist_url, download_path):
    playlist = Playlist(playlist_url)
    if not os.path.exists(download_path):
        os.makedirs(download_path)
    audio_files = []
    for video in playlist.videos:
        
        if len(audio_files) == 100:
            break
            
        print(f"Downloaded {len(audio_files)}")
    
        try:
            audio_stream = video.streams.filter(only_audio=True).first()
            output_path = audio_stream.download(output_path=download_path)
            base, ext = os.path.splitext(output_path)
            new_file = base + '.wav'
            AudioSegment.from_file(output_path).export(new_file, format="wav")
            os.remove(output_path)
        except Exception as e:
            print(f"Error: {e}")
            continue
        audio_files.append(new_file)
    return audio_files


rock_playlist = "https://youtube.com/playlist?list=PLyORnIW1xT6wFALM5dZlkFhOULbToFok3&si=Rd7b2VIsfiyE8uy9"
pop_playlist = "https://youtube.com/playlist?list=PLMC9KNkIncKtGvr2kFRuXBVmBev6cAJ2u&si=jO19iJUeivioOO16"
classical_playlist = "https://youtube.com/playlist?list=PL68AC80CBF3649BBB&si=Bq-KHuMN917vLZ_S"

download_dir = "../Data/downloaded_audio"

download_audio_from_playlist(rock_playlist, os.path.join(download_dir, "rock"))
download_audio_from_playlist(pop_playlist, os.path.join(download_dir, "pop"))
download_audio_from_playlist(classical_playlist, os.path.join(download_dir, "classical"))
# Out:
# Downloaded 0
# Downloaded 1
# Downloaded 2
# Downloaded 3
# Downloaded 4
# Downloaded 5
# Downloaded 6
# Downloaded 7
# Downloaded 8
# Downloaded 9
# Downloaded 10
# Downloaded 11
# Downloaded 12
# Downloaded 13
# Downloaded 14
# Downloaded 15
# Downloaded 16
# Downloaded 17
# Downloaded 18
# Downloaded 19
# Downloaded 20
# Downloaded 21
# Downloaded 22
# Downloaded 23
# Downloaded 24
# Downloaded 25
# Downloaded 26
# Downloaded 27
# Downloaded 28
# Downloaded 29
# Downloaded 30
# Downloaded 31
# Downloaded 32
# Downloaded 33
# Error: FRj0xuPF6Es is age restricted, and can't be accessed without logging in.
# Downloaded 33
# Downloaded 34
# Downloaded 35
# Downloaded 36
# Downloaded 37
# Downloaded 38
# Downloaded 39
# Error: bHi6NWXr0jI is age restricted, and can't be accessed without logging in.
# Downloaded 39
# Downloaded 40
# Downloaded 41
# Downloaded 42
# Downloaded 43
# Downloaded 44
# Downloaded 45
# Downloaded 46
# Downloaded 47
# Downloaded 48
# Downloaded 49
# Downloaded 50
# Downloaded 51
# Downloaded 52
# Downloaded 53
# Downloaded 54
# Downloaded 55
# Downloaded 56
# Downloaded 57
# Downloaded 58
# Downloaded 59
# Downloaded 60
# Downloaded 61
# Downloaded 62
# Downloaded 63
# Downloaded 64
# Downloaded 65
# Downloaded 66
# Downloaded 67
# Error: S76CGGPqI3s is age restricted, and can't be accessed without logging in.
# Downloaded 67
# Downloaded 68
# Downloaded 69
# Downloaded 70
# Downloaded 71
# Downloaded 72
# Downloaded 73
# Downloaded 74
# Downloaded 75
# ['C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Piotr Ilich Tchaikovsky - 1812 Overture (Finale).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Wolfgang Amadeus Mozart Eine kleine Nachtmusik.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Bach Toccata and Fugue in D minor BWV 565.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Rossini William Tell Overture Final.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Johann Pachelbel - Canon in D Major.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Johann Strauss II - The Blue Danube Waltz.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Carmina Burana  O Fortuna  Carl Orff  André Rieu.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Richard Strauss - Also Sprach Zarathustra  2001 Space Odyssey opening theme.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Offenbach - Infernal Galop.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Händel Messiah - Hallelujah Chorus.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Georges Bizet - Les Toreadors from Carmen Suite No 1.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\BEETHOVENODE TO JOY.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Sir Edward Elgar - Pomp and Circumstance March No1.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Amilcare Ponchielli - Dance of the Hours.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Mendelssohns Wedding March.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Moonlight Sonata.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Dance of the Sugar Plum Fairy on the Glass Armonica.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Waltz Over the Waves (Juventino Rosas)  Вальс Над волнами (Хувентино Росас).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Imperial March or Darth Vaders Theme.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Julius Fucik - Entry of the Gladiators.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\The Flower Duet (Lakmé).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Paul Abraham Dukas - Sorcerers Apprentice.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Hoe Down from rodeo.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Wagner - RIDE OF THE VALKYRIES - Furtwangler.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Palladio.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Frédéric Chopin - Marche Funèbre - Funeral March.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Tchaikovsky Nutcracker Suite - Russian Dance Trepak.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Johannes Brahms - Lullaby.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Aaron Copland - Fanfare for the Common Man.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\La gazza ladra (The Thieving Magpie).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Flight of the Bumblebee.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Carnival of the Animals Aquarium.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Franz von Suppé  Light Cavalry - Overture.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Sousa - The Washington Post March.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\BOLERO-RAVEL.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Camille Saint-Saëns - Danse Macabre.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Turkish March Mozart - Rondo Alla Turca.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\United States of America Anthem (The Star-Spangled Banner).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\La Marseillaise - Mireille Mathieu.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Autumn - Vivaldi.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Vivaldi - Four Seasons (Winter).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Mozarts Symphony no 40 - 1st movement.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Gioachino Rossini  The Barber Of Seville - Overture.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Egyptian March.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Adiemus.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Giuseppe Verdi - Aida - Marcia Trionfale (Triumphal March).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Jean-Jacques Perrey - The Elephant Never Forgets.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Aram Khachaturian - Sabre Dance.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Verdi - Traviata.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Love is blue.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\ANDREA BOCELLI (HQ) AVE MARIA (SCHUBERT).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Yundi Li - Chopin Fantasie Impromptu Op 66.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Jean-Jacques Perrey - Baroque Hoedown.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\A Beautiful Mind 01 A Kaleidoscope of Mathematics (James Horner).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Psyche Rock - Pierre Henry.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Beethoven - Symphony No 9 op 125 - Second Movement (Part 1 of 2) Period Instruments.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\JS Bach - Minuet and Badinerie from Orchestral Suite No 2 in B.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Clair de lune - Debussy.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Bach - Cello Suite No1 i-Prelude.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Mozart - Requiem.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Luigi Boccherini Minuetto (classical).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\The Sting Theme (Joplin - The Entertainer).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Johann Strauss Sr - Radetzky March.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\George Frideric Handel - The Arrival of the Queen of Sheba.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Dam Busters Theme [Highest Quality].wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Antonin Dvorak - Symphony No9- Allegro con fuoco 12.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Liszt Liebestraum No 3 Notturno (Barenboim).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\06 Tea (Chinese Dance) - The Nutcracker Suite.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Tchaikovsky - Piano Concerto 1 (B Flat Minor).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Edvard Grieg Peer Gynt - Morning Mood.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Mendelssohn  Spring Song.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Pollini plays Chopin Etude Op10 No12 Revolutionary.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Pavarotti - Vesti La Giubba.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Por una cabeza (Arr John Williams).wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\National Anthem of Colombia (Oh gloria inmarcesible) - André Rieu.wav',
#  'C:\\Users\\szabu\\PycharmProjects\\ML_basics_project\\Notebooks\\../Data/downloaded_audio\\classical\\Maksim Mrvica - Croatian Rhapsody (LIVE).wav']

# %% [markdown]
# ## Dividing audio into 3 seconds long snippets, after that doing train/test split (to avoid data leakage)

# %%
def get_files_and_labels(download_dir):
    genre_dirs = ["rock", "pop", "classical"]
    all_files = []
    all_labels = []
    for genre in genre_dirs:
        genre_path = os.path.join(download_dir, genre)
        if os.path.exists(genre_path):
            files = [os.path.join(genre_path, f) for f in os.listdir(genre_path) if f.endswith('.wav')]
            labels = [genre] * len(files)
            all_files.extend(files)
            all_labels.extend(labels)
    return all_files, all_labels

def split_audio(file_path, clip_length=3000):
    audio = AudioSegment.from_wav(file_path)
    clips = []
    for i in range(0, len(audio), clip_length):
        clip = audio[i:i + clip_length]
        if len(clip) == clip_length:
            clip_path = f"{file_path[:-4]}_clip_{i // clip_length}.wav"
            clip.export(clip_path, format="wav")
            clips.append(clip_path)
    return clips

def extract_audio_features_from_clips(clips, label):
    features = []
    for clip in clips:
        feature_dict = extract_audio_features(clip)
        feature_dict['label'] = label
        features.append(feature_dict)
        os.remove(clip)
    return features

def process_files(audio_files, labels):
    all_features = []
    for file_path, label in zip(audio_files, labels):
        print(f"Started processing {file_path}")
        clips = split_audio(file_path)
        features = extract_audio_features_from_clips(clips, label)
        all_features.extend(features)
    return all_features

download_dir = "../Data/downloaded_audio_cutting"
all_files, all_labels = get_files_and_labels(download_dir)

train_files, test_files, train_labels, test_labels = train_test_split(all_files, all_labels, test_size=0.2, random_state=42, stratify=all_labels)

train_features = process_files(train_files, train_labels)
test_features = process_files(test_files, test_labels)
# Out:
# Started processing ../Data/downloaded_audio_cutting\pop\Shape of You.wav
# C:\Users\szabu\anaconda3\envs\classical-ml\Lib\site-packages\librosa\core\pitch.py:101: UserWarning: Trying to estimate tuning from empty frequency set.
#   return pitch_tuning(
wav
# Started processing ../Data/downloaded_audio_cutting\classical\Wagner - RIDE OF THE VALKYRIES - Furtwangler.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Secondhand Heart.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Shut Up About It.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Mia Baron - Together Again (Lyric Video).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Linger.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Monster.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Carnival of the Animals Aquarium.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Work from Home (Official Video).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Piotr Ilich Tchaikovsky - 1812 Overture (Finale).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Africa (Official HD Video).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Another Day In Paradise (Live).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Jean-Jacques Perrey - The Elephant Never Forgets.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Dont Stop Me Now.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Bad Romance.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Minefields.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Beethoven - Symphony No 9 op 125 - Second Movement (Part 1 of 2) Period Instruments.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Walt Disco - Come Undone.wav
# Started processing ../Data/downloaded_audio_cutting\rock\I Was Made For Lovin You.wav
# Started processing ../Data/downloaded_audio_cutting\rock\We Will Rock You.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Johann Strauss II - The Blue Danube Waltz.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Youre Beautiful.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Decode (Twilight Soundtrack Version).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Sex on Fire (Official Video).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Poker Face.wav
# Started processing ../Data/downloaded_audio_cutting\rock\The Chooches - Crying for You (ft Junior Paes).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Verdi - Traviata.wav
# Started processing ../Data/downloaded_audio_cutting\rock\The Reason Closed Captioned.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Offenbach - Infernal Galop.wav
# Started processing ../Data/downloaded_audio_cutting\classical\The Sting Theme (Joplin - The Entertainer).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Linkin Park - Castle of Glass.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Right Here Waiting (Official Music Video).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Mirrors (Official Video).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Edvard Grieg Peer Gynt - Morning Mood.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Numb.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Paint It Black.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Guster - When We Were Stars [Official Lyric Video].wav
# Started processing ../Data/downloaded_audio_cutting\classical\Rossini William Tell Overture Final.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Diamonds.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Adele - Skyfall (Live - One Night Only).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Tchaikovsky Nutcracker Suite - Russian Dance Trepak.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Baby.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Shallow (from A Star Is Born) (Official Music Video).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Aram Khachaturian - Sabre Dance.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Just Give Me A Reason.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Dont Cry Original Version.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Flight of the Bumblebee.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Moonlight Sonata.wav
# Started processing ../Data/downloaded_audio_cutting\pop\You Are The Reason (Duet Version).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Always Remember Us This Way (from A Star Is Born) (Official M.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Like a Stone (Official Video).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Sweet Child O Mine Version 2 Black And White.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Another One Bites the Dust.wav
# Started processing ../Data/downloaded_audio_cutting\pop\You Don’t.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Please Forgive Me Radio Version.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Intentions (Official Video (Short Version)).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Memories (Official Video).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Señorita.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Eye Of The Tiger (Official HD Video).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Whenever Wherever (Official HD Video).wav
# Started processing ../Data/downloaded_audio_cutting\pop\Cristina Hron - Cherry Fairy (Official Video).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Centuries.wav
# Started processing ../Data/downloaded_audio_cutting\rock\I Dont Want to Miss a Thing (Official HD Video).wav
# Started processing ../Data/downloaded_audio_cutting\rock\Kryptonite.wav
# Started processing ../Data/downloaded_audio_cutting\rock\Come As You Are.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Nineteen.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Camille Saint-Saëns - Danse Macabre.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Bach Toccata and Fugue in D minor BWV 565.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Viva la Vida.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Rewrite the Stars.wav
# Started processing ../Data/downloaded_audio_cutting\classical\Dam Busters Theme [Highest Quality].wav
# Started processing ../Data/downloaded_audio_cutting\rock\Every Breath You Take Video.wav
# Started processing ../Data/downloaded_audio_cutting\pop\Im Yours (4K Remaster).wav
# Started processing ../Data/downloaded_audio_cutting\classical\Franz von Suppé  Light Cavalry - Overture.wav

# %% [markdown]
# ## Creating dataframes for later use

# %%
train_df = pd.DataFrame(train_features)
test_df = pd.DataFrame(test_features)

train_df.to_csv('train_features.csv', index=False)
test_df.to_csv('test_features.csv', index=False)
# Out:
# Feature extraction and dataset creation completed successfully.
